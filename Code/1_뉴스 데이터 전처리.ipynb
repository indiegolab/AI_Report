# %%
import pandas as pd
import re
news = pd.read_csv('./data/news_data/news_samgsung_skhinix.csv',encoding = 'utf-8',engine='python')

# %%
# from konlpy.tag import Mecab
# mecab = Mecab()
# from ekonlpy.sentiment import MPCK
# mpck = MPCK()
# mpck.tokenize(df['content'][i])

# %%
import pandas as pd
news=pd.read_csv('./data/news_data/news_samgsung_skhinix.csv',encoding = 'utf-8',engine='python')

# %%
news_sample = news[:2000]

# %%
news_sample.to_csv('./data/news_data/news_sample.csv',encoding='utf-8',index=False)

# %%
import pandas as pd
news_sample = pd.read_csv('./data/news_data/news_sample.csv',encoding='utf-8')

# %%
news_sample2= news_sample[:100]

# %%
import KimModule.News_data_preprocessing as kim
NEWS =kim.News_PreProcessing(news_sample2)
news = NEWS.content_pre()
news.head(2)
# Out:
#    Unnamed: 0  type                 date media  \
# 0           0  news  2019-08-31 20:01:00  서울일보
# 1           1  news  2019-08-31 20:00:00  서울경제
#
#                                           title  \
# 0  판깨스트 국정농단 상고심박근혜 2심 김문석 vs 이재용 2심 정형식 판결 재조명
# 1                  출시되도 사긴 어렵다...한정판 등극한 갤럭시 폴드
#
#                                              content  \
# 0  박근혜왼쪽 전 대통령과 이재용 삼성전자 부회장. 연합2016년 말 전국에 들불처럼 ...
# 1  갤럭시폴드 9월 6일 국내 출시 유력자급제 위주 극소 물량만 공급화웨이 메이트X와 ...
#
#                                                  url
# 0  https://www.seoul.co.kr/news/newsView.php?id=2...
# 1        https://www.sedaily.com/NewsView/1VN6NE5XNI

# %%
len(news)
# Out:
# 92

# %%
news = NEWS.tokens_ngram('./data/news_data/news_sample_ngram_ver4.csv')
news
# Out:
# C:\Users\khjin\khj_python\산업분석\KimModule\News_data_preprocessing.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   news['tokens'][i] = ','.join(tokens)
# C:\Users\khjin\khj_python\산업분석\KimModule\News_data_preprocessing.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   news['bigram'][i] = ','.join(bi_gram)
# C:\Users\khjin\khj_python\산업분석\KimModule\News_data_preprocessing.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
import pandas as pd
news = pd.read_csv('./data/news_data/news_sample_ngram_ver4.csv')

# %%
news.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  type                 date   media  \
# 0           0             0  news  2019-08-31 20:01:00    서울일보
# 1           1             1  news  2019-08-31 20:00:00    서울경제
# 2           2             2  news  2019-08-31 13:08:00  디지털타임스
# 3           3             3  news  2019-08-31 12:29:00    이데일리
# 4           4             4  news  2019-08-31 12:24:00     YTN
#
#                                           title  \
# 0  판깨스트 국정농단 상고심박근혜 2심 김문석 vs 이재용 2심 정형식 판결 재조명
# 1                  출시되도 사긴 어렵다...한정판 등극한 갤럭시 폴드
# 2               삼성 중장기 성장 전략 차질 우려에 글로벌경영 시계 제로
# 3                       밑줄 쫙 박근혜이재용 안돼 그러니까 돌아가
# 4              삼성 불법파견 은폐 정현옥 전 고용노동부 차관 1심서 무죄
#
#                                              content  \
# 0  박근혜왼쪽 전 대통령과 이재용 삼성전자 부회장. 연합2016년 말 전국에 들불처럼 ...
# 1  갤럭시폴드 9월 6일 국내 출시 유력자급제 위주 극소 물량만 공급화웨이 메이트X와 ...
# 2  삼성전자 이재용 부회장이 29일 대법원에서 원심 파기 환송 판결을 받으면서 삼성은 ...
# 3  박근혜이재용 안돼바꿔돌아가 문준용 부당해 목소리 내야 한다 한국 대통령이 동네북이냐...
# ...

# %%
len(news)
# Out:
# 92

# %%
if len(news['tokens'][0].lower().split(',')[0].split('/')[0])>1:
    print('ok')
else:
    print('no')
# Out:
# ok
